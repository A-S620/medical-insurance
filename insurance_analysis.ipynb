# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('insurance.csv')

df.groupby(['region']).size().plot(kind='pie', autopct='%1.1f%%', ylabel='', title='The percentage of each region in the data set')
# Out:
# <AxesSubplot:title={'center':'The percetage of each region in the data set'}>
